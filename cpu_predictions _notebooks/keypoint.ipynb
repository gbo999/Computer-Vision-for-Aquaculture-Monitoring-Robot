# %%
from ultralytics import YOLO

# %%
from PIL import Image
import os

# Source and destination folders
source_folder = r'C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\car try to add for test\for carapace'
destination_folder = r'C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\car try to add for test\for carapace\resized_images'

# Create the destination folder if it does not exist
os.makedirs(destination_folder, exist_ok=True)

# Resize dimensions
resize_dimensions = (640, 640)

# Function to resize images
def resize_image(image_path, output_path, size):
    with Image.open(image_path) as img:
        img = img.resize(size, Image.LANCZOS)
        img.save(output_path)

# Process each image in the source folder
for filename in os.listdir(source_folder):
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        source_file = os.path.join(source_folder, filename)
        destination_file = os.path.join(destination_folder, filename)
        resize_image(source_file, destination_file, resize_dimensions)
        print(f"Resized and saved: {destination_file}")

print("All images have been resized.")
# Out:
# Resized and saved: C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\car try to add for test\for carapace\resized_images\GX010157_159_2240.jpg
# Resized and saved: C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\car try to add for test\for carapace\resized_images\GX010157_173_2554.jpg
# Resized and saved: C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\car try to add for test\for carapace\resized_images\GX010157_272_4575.jpg
# Resized and saved: C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\car try to add for test\for carapace\resized_images\GX010157_279_4893.jpg
# Resized and saved: C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\car try to add for test\for carapace\resized_images\GX010157_293_5205.jpg
# ...

# %%
model = YOLO(r"C:\Users\gbo10\OneDrive\מסמכים\הורדות\best (16).pt")  

model.predict(r'C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\left\leftresized', save=True,save_txt=True, imgsz=640, conf=0.25,show_boxes=True)
# Out:
# image 1/5 C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\left\leftresized\GX010089_11_236.jpg_gamma_stabilized_00001.png: 640x640 6 prawn-models, 1314.6ms
# image 2/5 C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\left\leftresized\GX010091_5_149.jpg_gamma_stabilized_00001.png: 640x640 6 prawn-models, 1144.4ms
# image 3/5 C:\Users\gbo10\OneDrive\measurement_paper_images\images used for imageJ\check\stabilized\left\leftresized\GX010102_50_1396.jpg_gamma_stabilized_00001.png: 640x640 5 prawn-models, 786.3ms
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\1.4.2024\56\GX010150_25_418.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\90 lux\GX010156_53_629.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\90 lux\GX010157_159_2240.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\90 lux\GX010157_173_2554.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\90 lux\GX010157_272_4575.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\90 lux\GX010157_279_4893.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\90 lux\GX010157_293_5205.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\29 lux\gamma\GX010154_66_933.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\7.4.2024\29 lux\gamma\GX010154_147_2340.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\10.4.2024\curtain closed\gamma\GX010161_56_705.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\10.4.2024\curtain closed\gamma\GX010162_153_2230.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\10.4.2024\curtain closed\gamma\GX010162_163_2433.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\10.4.2024\curtain closed\gamma\GX010162_250_4175.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\10.4.2024\curtain closed\gamma\GX010163_61_864.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\10.4.2024\curtain closed\gamma\GX010164_82_1188.jpg_gamma.jpg',
    r'C:\Users\gbo10\OneDrive\measurement_paper_images\each video from research extracted to images\car\10.4.2024\curtain open\GX010165_72_934.jpg'
]


# Destination folder
destination_folder = r'C:\Users\gbo10\Videos\data-science\Research-counting-algorithms\runs\pose\predict12\to think'

# Create the destination folder if it does not exist
os.makedirs(destination_folder, exist_ok=True)

# Copy each file to the new folder
for file_path in files_to_copy:
    shutil.copy(file_path, destination_folder)

print("Files copied successfully.")
# Out:
# Files copied successfully.
