# %%
import pandas as pd

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

df=pd.read_csv(f'/Users/gilbenor/Documents/code projects/msc/counting_research_algorithms/fifty_one/measurements/length_analysis.csv')


def drop_measurements_outside_range(df, min_val_big=170, max_val_big=220, min_val_small=120, max_val_small=170):
    """
    Drop rows where measurements fall outside the specified range.
    Only considers non-null values.
    """
    # Create masks for big and small measurements within range
    big_mask = (df['big_total_length'].between(min_val_big, max_val_big)) | (df['big_total_length'].isna())
    small_mask = (df['small_total_length'].between(min_val_small, max_val_small)) | (df['small_total_length'].isna())
    
    # Keep rows where both measurements are valid or null
    return df[big_mask & small_mask]

# Drop measurements outside reasonable range (100-250mm)
df = drop_measurements_outside_range(df)


#split data by pond type
df['pond_type']=df['image_name'].str.split('_').str[1]

mapping_pond_type = {
    'GX010192': 'square',
    'GX010193': 'square', 
    'GX010194': 'square',
    'GX010191': 'circle',
    
}

df['pond_type'] = df['pond_type'].map(mapping_pond_type)


df['pond_type'].groupby(df['pond_type']).count()


#take random 35 from circle pond
circle_pond = df[df['pond_type'] == 'circle']
circle_pond = circle_pond.sample(n=35)

#take random 35 from square pond
square_pond = df[df['pond_type'] == 'square']
square_pond = square_pond.sample(n=15)

# %%
combined_pond = pd.concat([circle_pond, square_pond])

combined_pond
# Out:
#                            image_name  big_total_length  big_carapace_length  \
# 48   undistorted_GX010191_90_1036.jpg             208.5                 49.3
# 27   undistorted_GX010191_35_1167.jpg             213.7                 51.0
# 21    undistorted_GX010191_28_230.jpg             208.2                 47.4
# 10  undistorted_GX010191_114_1383.jpg               NaN                  NaN
# 49   undistorted_GX010191_94_1132.jpg             185.3                 39.0
# 17    undistorted_GX010191_16_495.jpg               NaN                  NaN
# 43     undistorted_GX010191_5_190.jpg             213.2                 47.0
# 15    undistorted_GX010191_14_460.jpg             191.2                 48.1
# 28    undistorted_GX010191_35_367.jpg             184.9                 43.9
# 46   undistorted_GX010191_88_1016.jpg             197.1                 49.3
# 18    undistorted_GX010191_17_509.jpg             193.8                 48.4
# 47     undistorted_GX010191_8_309.jpg             206.9                 44.9
# 8     undistorted_GX010191_10_370.jpg               NaN                  NaN
# 4   undistorted_GX010191_105_1312.jpg             202.2                 47.3
# 38   undistorted_GX010191_46_1396.jpg             175.8                 45.6
# 0   undistorted_GX010191_100_1250.jpg             185.8                 44.3
# 24    undistorted_GX010191_32_305.jpg             211.1                 44.9
# 12  undistorted_GX010191_117_1408.jpg             183.8                 45.4
# 40    undistorted_GX010191_47_507.jpg             191.1                 47.3
# 20    undistorted_GX010191_27_215.jpg             203.6                 44.3
# 34   undistorted_GX010191_42_1339.jpg             195.6                 48.0
# 25   undistorted_GX010191_34_1128.jpg             199.0                 44.6
# 32   undistorted_GX010191_41_1322.jpg             189.6                 47.9
# 1   undistorted_GX010191_101_1265.jpg             191.7                 44.4
# 35    undistorted_GX010191_42_457.jpg             186.2                 45.4
# 26    undistorted_GX010191_34_350.jpg             195.3                 43.3
# 36     3031.8     1862.0               150.3                   31.1
# 13     4084.1      666.2                 NaN                    NaN
# 31     3847.1      647.7               156.7                   43.0
# 16        NaN        NaN               145.1                   39.4
# 71        NaN        NaN               158.1                   34.1
# 67        NaN        NaN               162.1                   37.3
# 69        NaN        NaN               126.4                   29.2
# 62     2679.6     2007.6                 NaN                    NaN
# 77        NaN        NaN               149.2                   36.9
# 58        NaN        NaN               155.0                   40.7
# 94     2253.3      704.6                 NaN                    NaN
# 88        NaN        NaN               144.8                   34.8
# 86        NaN        NaN               157.5                   37.5
# 68        NaN        NaN               152.1                   37.9
# 91        NaN        NaN               159.8                   41.8
# 92        NaN        NaN               147.4                   38.1
# 70        NaN        NaN               155.2                   37.9
# 74        NaN        NaN               140.4                   35.5
# 80        NaN        NaN               146.0                   36.7
#
#     small_eye_x  small_eye_y pond_type
# 48          NaN          NaN    circle
# 27       3271.9        678.1    circle
# 21       2680.0        408.3    circle
# 10       4775.6        487.1    circle
# 49       3435.0        517.9    circle
# 17       4310.0       2736.7    circle
# 43          NaN          NaN    circle
# 15          NaN          NaN    circle
# 28       3237.3       1989.5    circle
# 46          NaN          NaN    circle
# 18        780.1       2760.0    circle
# 47       2899.3       1448.1    circle
# 8        3275.6       1976.4    circle
# 4        3238.0       2205.4    circle
# 38          NaN          NaN    circle
# 0        2861.3       1433.4    circle
# 24       2916.1       1451.4    circle
# 12          NaN          NaN    circle
# 40       4636.6       2687.8    circle
# 20          NaN          NaN    circle
# 34          0.0          0.0    circle
# 25       3431.8        454.5    circle
# 32       3537.3       2270.2    circle
# 1           NaN          NaN    circle
# 35          NaN          NaN    circle
# 26       3141.2       1908.9    circle
# 29       3197.9        765.1    circle
# 5           NaN          NaN    circle
# 9        4396.5       1709.1    circle
# 22          NaN          NaN    circle
# 30       2924.2       1226.3    circle
# 36       4389.4       1748.8    circle
# 13          NaN          NaN    circle
# 31       2821.3       1621.4    circle
# 16       4083.0       2576.3    circle
# 71       2855.8        772.0    square
# 67       2346.8       1199.8    square
# 69        706.9       1453.7    square
# 62          NaN          NaN    square
# 77       1905.9       1524.8    square
# 58       2338.8       1954.3    square
# 94          NaN          NaN    square
# 88       2931.3        653.6    square
# 86       2394.4       2021.8    square
# 68       1565.7       1146.7    square
# 91       2094.8        969.7    square
# 92       4497.1        496.3    square
# 70       3632.7        977.2    square
# 74       2440.6       2308.4    square
# 80       1605.1       1825.0    square

# %%
#copy images to new folder
import shutil

import tqdm

os.makedirs('images_new', exist_ok=True)
for index, row in tqdm.tqdm(combined_pond.iterrows()):
    src_path = f'/Users/gilbenor/Documents/code projects/msc/counting_research_algorithms/runs/pose/predict57/viz_real/viz_{row["image_name"]}'
    dst_path = f'//Users/gilbenor/Library/CloudStorage/OneDrive-post.bgu.ac.il/thesisi/thesis document/images to watch/{row["image_name"]}'
    shutil.copy(src_path, dst_path)
# Out:
# 50it [00:00, 1241.09it/s]

# %%
combined_pond.to_csv('combined_pond.csv', index=False)
