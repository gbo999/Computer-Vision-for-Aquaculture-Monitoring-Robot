# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO("C:/Users/gbo10/OneDrive/measurement_paper_images/sam_experiments/pose right/best (7).pt")

# Run inference on 'bus.jpg' with arguments
model.predict("C:/Users/gbo10/OneDrive/measurement_paper_images/to colab/test with seperation/images/right round/GX010080_212_2954-jpg_gamma_jpg.rf.1aff7846fd565ba2c7384ff0a14cd8ab.jpg", save=True,conf=0.7, imgsz=640)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 model = YOLO("C:/Users/gbo10/OneDrive/measurement_paper_images/sam_experiments/pose right/best (7).pt")
#       6 # Run inference on 'bus.jpg' with arguments
# ----> 7 model.predict("C:/Users/gbo10/OneDrive/measurement_paper_images/to colab/test with seperation/images/right round/jpg_gamma_jpg.rf.1aff7846fd565ba2c7384ff0a14cd8ab.jpg", save=True,conf=0.7, imgsz=640)
#
# File c:\Users\gbo10\Videos\research\counting_research_algorithms\.venv\lib\site-packages\ultralytics\engine\model.py:442, in Model.predict(self, source, stream, predictor, **kwargs)
#     440 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     441     self.predictor.set_prompts(prompts)
# --> 442 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\gbo10\Videos\research\counting_research_algorithms\.venv\lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\gbo10\Videos\research\counting_research_algorithms\.venv\lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\gbo10\Videos\research\counting_research_algorithms\.venv\lib\site-packages\ultralytics\engine\predictor.py:226, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     222     self.setup_model(model)
#     224 with self._lock:  # for thread-safe inference
#     225     # Setup source every time predict is called
# --> 226     self.setup_source(source if source is not None else self.args.source)
#     228     # Check if save_dir/ label file exists
#     229     if self.args.save or self.args.save_txt:
#
# File c:\Users\gbo10\Videos\research\counting_research_algorithms\.venv\lib\site-packages\ultralytics\engine\predictor.py:198, in BasePredictor.setup_source(self, source)
#     188 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     189 self.transforms = (
#     190     getattr(
#     191         self.model.model,
#    (...)
#     196     else None
#     197 )
# --> 198 self.dataset = load_inference_source(
#     199     source=source,
#     200     batch=self.args.batch,
#     201     vid_stride=self.args.vid_stride,
#     202     buffer=self.args.stream_buffer,
#     203 )
#     204 self.source_type = self.dataset.source_type
#     205 if not getattr(self, "stream", True) and (
#     206     self.source_type.stream
#     207     or self.source_type.screenshot
#     208     or len(self.dataset) > 1000  # many images
#     209     or any(getattr(self.dataset, "video_flag", [False]))
#     210 ):  # videos
#
# File c:\Users\gbo10\Videos\research\counting_research_algorithms\.venv\lib\site-packages\ultralytics\data\build.py:202, in load_inference_source(source, batch, vid_stride, buffer)
#     200     dataset = LoadPilAndNumpy(source)
#     201 else:
# --> 202     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride)
#     204 # Attach source types to the dataset
#     205 setattr(dataset, "source_type", source_type)
#
# File c:\Users\gbo10\Videos\research\counting_research_algorithms\.venv\lib\site-packages\ultralytics\data\loaders.py:292, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride)
#     290         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     291     else:
# --> 292         raise FileNotFoundError(f"{p} does not exist")
#     294 # Define files as images or videos
#     295 images, videos = [], []
#
# FileNotFoundError: C:/Users/gbo10/OneDrive/measurement_paper_images/to colab/test with seperation/images/right round/jpg_gamma_jpg.rf.1aff7846fd565ba2c7384ff0a14cd8ab.jpg does not exist
