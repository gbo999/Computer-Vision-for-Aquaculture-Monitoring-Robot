# %%
import pandas as pd
import os

# Get the current working directory
work_dir = os.getcwd()

# Specify the path to your CSV file
csv_file = f'{work_dir}/output/stats.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file,delimiter=';')
df
# Out:
#      global_idx                                          file_name  \
# 0             0  C:\Users\gbo10\Videos\research\counting_resear...
# 1             1  C:\Users\gbo10\Videos\research\counting_resear...
# 2             1  C:\Users\gbo10\Videos\research\counting_resear...
# 3             2  C:\Users\gbo10\Videos\research\counting_resear...
# 4             2  C:\Users\gbo10\Videos\research\counting_resear...
# ..          ...                                                ...
# 163          53  C:\Users\gbo10\Videos\research\counting_resear...
# 164          53  C:\Users\gbo10\Videos\research\counting_resear...
# 165          53  C:\Users\gbo10\Videos\research\counting_resear...
# 166          53  C:\Users\gbo10\Videos\research\counting_resear...
# 167          53  C:\Users\gbo10\Videos\research\counting_resear...
#
#      frame_index          blur_score  is_blurry  is_black  last_frame_index  \
# 0              0  185,11760313968412      False       NaN               NaN
# ...
